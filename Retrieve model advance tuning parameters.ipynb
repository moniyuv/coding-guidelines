# %% [markdown]
# #### More information about the API can be found on: https://datarobot-public-api-client.readthedocs-hosted.com/en/v2.17.0/#

# %%
import requests
import os
import datarobot as dr
import pandas as pd
import yaml
import re
import numpy as np

# %%
with open('/Users/souriyo.soumpholphakdy/Documents/config/drconfig.yaml', 'r') as f:
    drconfig = yaml.safe_load(f)
    
#Yaml contains connection information:
#DATAROBOT_API_TOKEN: <look into your profile>
#DATAROBOT_ENDPOINT: <your datarobot url>/api/v2/
#DATAROBOT_USERNAME: john.doe@cimb.com

# %% [markdown]
# #### Connect to DataRobot via Python modelling API

# %%
response = dr.Client(token=drconfig['DATAROBOT_API_TOKEN'], endpoint=drconfig['DATAROBOT_ENDPOINT'])

# %% [markdown]
# ### List available projects

# %%
#enter project name
project_name='Lending_Club'

# %%
project_list=dr.Project.list(search_params={'project_name': project_name})
project_list
# Out:
# [Project(10K_Lending_Club_Loans.xlsx),
#  Project(10K_Lending_Club_Loans.xlsx),
#  Project(10K_Lending_Club_Loans.xlsx),
#  Project(10K_Lending_Club_Loans.xlsx),
#  Project(10K_Lending_Club_Loans.xlsx),
#  Project(10K_Lending_Club_Loans.xlsx),
#  Project(10K_Lending_Club_Loans.xlsx),
#  Project(AI_Exp_10K_Lending_Club_Loans.xlsx),
#  Project(DemoReady_10K_Lending_Club_Loans),
#  Project(Playground_10K_Lending_Club_Loans.xlsx)]

# %%
i = 0
#init empty dataframe of project
df_projects= pd.DataFrame({'project_name': [], 'id': []})

#loop through list of project and insert to empty dataframe
for project in project_list:
    df_projects = df_projects.append(
        {'project_name': project.project_name,
         'id': project.id
        }, ignore_index=True)
    i += 1

df_projects
# Out:
#                              project_name                        id
# 0             10K_Lending_Club_Loans.xlsx  5dcbc7c97be8693b0818924b
# 1             10K_Lending_Club_Loans.xlsx  5dcbbe807be8693a9c1891f8
# 2             10K_Lending_Club_Loans.xlsx  5dcbaccb7be869395218923b
# 3             10K_Lending_Club_Loans.xlsx  5dcba7be80155f38141cb703
# 4             10K_Lending_Club_Loans.xlsx  5dcb9f1a80155f37601cb715
# 5             10K_Lending_Club_Loans.xlsx  5dcb992280155f36ba1cb78a
# 6             10K_Lending_Club_Loans.xlsx  5dcb9421baa39437d5ce0cb0
# 7      AI_Exp_10K_Lending_Club_Loans.xlsx  5dc0eb21fddc7a6bd857eb68
# 8        DemoReady_10K_Lending_Club_Loans  5d8afb8c78132c62f49dda1d
# 9  Playground_10K_Lending_Club_Loans.xlsx  5d7616e478132c4893cd2650

# %% [markdown]
# ### Connection to the project
# #### Input the project id to connect to

# %%
#enter project id
selected_project='5d8afb8c78132c62f49dda1d'

# %%
project = dr.Project.get(project_id=selected_project)

# %% [markdown]
# ### Get project models information

# %%
models = project.get_models()

def get_results (proj):
    """Args: A DataRobot project object
       returns: A dataframe sorted by log loss for cross-validation"""
    project= dr.Project.get(project_id=proj)
    
    #extract featurelist
    feature_lists = project.get_featurelists()
    
    #get informative features, the default for autopilot
    #you could update this to your feature list
    f_list = [lst for lst in feature_lists if
                     lst.name == 'Informative Features'][0]
    
    #get models
    models = project.get_models()
    flist_models = [model for model in models if model.featurelist_id == f_list.id]
    
    #print results
    val_scores = pd.DataFrame([{'model_type': model.model_type,
                           'blueprint info': model.blueprint,
                           'model_id': model.id,
                           'sample_pct': model.sample_pct,
                           'featurelist': model.featurelist_name,
                           'val_logloss': model.metrics['LogLoss']['validation'],
                           'cross_val_logloss': model.metrics['LogLoss']['crossValidation']}
                           for model in flist_models if model.metrics['LogLoss'] is not None])
    
    return val_scores.sort_values(by='cross_val_logloss')

modelframe = get_results(project.id)
modelframe
# Out:
# /Users/souriyo.soumpholphakdy/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:28: DataRobotDeprecationWarning: `blueprint` has been deprecated in `v2.3`, will be removed in `v3.0`. Use Model.blueprint_id instead
#                                            model_type  \
# 0   eXtreme Gradient Boosted Trees Classifier with...
# 1   eXtreme Gradient Boosted Trees Classifier with...
# 2   eXtreme Gradient Boosted Trees Classifier with...
# 4   eXtreme Gradient Boosted Trees Classifier with...
# 3                         Generalized Additive2 Model
# ..                                                ...
# 75                                 RuleFit Classifier
# 76                    Naive Bayes combiner classifier
# 77                                Logistic Regression
# 78                    Decision Tree Classifier (Gini)
# 79                 Isolation Forest Anomaly Detection
#
#                                        blueprint info  \
# 0   Blueprint(eXtreme Gradient Boosted Trees Class...
# 1   Blueprint(eXtreme Gradient Boosted Trees Class...
# 2   Blueprint(eXtreme Gradient Boosted Trees Class...
# 4   Blueprint(eXtreme Gradient Boosted Trees Class...
# 3              Blueprint(Generalized Additive2 Model)
# ..                                                ...
# 75                      Blueprint(RuleFit Classifier)
# 76         Blueprint(Naive Bayes combiner classifier)
# 77                     Blueprint(Logistic Regression)
# 78         Blueprint(Decision Tree Classifier (Gini))
# 79      Blueprint(Isolation Forest Anomaly Detection)
#
#                     model_id  sample_pct           featurelist  val_logloss  \
# 0   5d8afffa95d0302e0d79d1a5        80.0  Informative Features      0.36088
# 1   5d8afdba95d0301e0179d192        64.0  Informative Features      0.36616
# 2   5d8afdba95d0301e0179d188        64.0  Informative Features      0.36761
# 4   5d8afdba95d0301e0179d183        64.0  Informative Features      0.36911
# 3   5d8afdba95d0301e0179d182        64.0  Informative Features      0.36777
# ..                       ...         ...                   ...          ...
# 75  5d8afc1a8978f3025493620d        16.0  Informative Features      0.41483
# 76  5d8afc1a8978f302549361ff        16.0  Informative Features      0.43670
# 77  5d8afc1a8978f30254936203        16.0  Informative Features      0.46486
# 78  5d8afc1a8978f30254936202        16.0  Informative Features      0.48316
# 79  5d8afc1b8978f3025493625b        16.0  Informative Features      0.52206
#
#     cross_val_logloss
# 0            0.354428
# 1            0.357712
# 2            0.358614
# 4            0.358808
# 3            0.359508
# ..                ...
# 75                NaN
# 76                NaN
# 77                NaN
# 78                NaN
# 79                NaN
#
# [80 rows x 7 columns]

# %%
print ("Other optimization metrics are available")
for metric in list(models[0].metrics.keys()):
    print ('- "' + metric + '"')
# Out:
# Other optimization metrics are available
# - "AUC"
# - "Rate@Top5%"
# - "Max MCC"
# - "RMSE"
# - "Kolmogorov-Smirnov"
# - "Rate@TopTenth%"
# - "LogLoss"
# - "FVE Binomial"
# - "Gini Norm"
# - "Rate@Top10%"

# %% [markdown]
# ### Get model Advance Tuning setup
# #### Input the model to target

# %%
selected_model='5d8afffa95d0302e0d79d1a5' #Regularized Logistic Regression (L2)

# %%
model = dr.Model.get(project=selected_project,model_id= selected_model)
tune = model.start_advanced_tuning_session()

# %%
#function to help format hyper param 
param_types = ['int','float','intlist','floatlist','select','ascii','unicode']

def parameters_to_df(params):
    df = pd.DataFrame.from_dict(params['tuning_parameters'])
    df['param_type'] = ''
    df['supports_grid_search'] = False
    df['min_val'] = np.nan
    df['max_val'] = np.nan
    df['values_select'] = None
    df['values_select'] = df['values_select'].astype(object)
    df['multiple_types'] = False
    for i in np.arange(df.shape[0]):
        main = 0
        base_resord = df.iloc[i:i+1,:].copy()
        for ptype in param_types:
            if (ptype in df.constraints.iloc[i]):
                k = i
                if main > 0:
                    df.loc[i,'multiple_types'] = True
                    df = df.append(base_resord,ignore_index = True)
                    k = df.shape[0]-1
                    df.loc[k,'multiple_types'] = True
                main += 1
                df.loc[k,'param_type'] = ptype
                
                constr = df.constraints.iloc[i][ptype]
                if 'supports_grid_search' in constr:
                    df.loc[k,'supports_grid_search'] = constr['supports_grid_search']
                if ptype in ['int','float']:
                    df.loc[k,'min_val'] = constr['min']
                    df.loc[k,'max_val'] = constr['max']
                if ptype in ['intlist','floatlist','select']:
                    df.at[k,'values_select'] = (constr['values'])
    df['parameter_name_type'] = df['parameter_name'] + '_' + df['param_type']
    return df

# %%
prms
# Out:
# {'tuning_description': None,
#  'tuning_parameters': [{'parameter_name': 'arbimp',
#    'parameter_id': 'eyJhcmciOiJhcmJpbXAiLCJ2aWQiOiIxMSJ9',
#    'default_value': -9999,
#    'current_value': -9999,
#    'task_name': 'Missing Values Imputed',
#    'constraints': {'int': {'min': -99999,
#      'max': 99999,
#      'supports_grid_search': False}}},
#   {'parameter_name': 'min_count_na',
#    'parameter_id': 'eyJhcmciOiJtaW5fY291bnRfbmEiLCJ2aWQiOiIxMSJ9',
#    'default_value': 5,
#    'current_value': 5,
#    'task_name': 'Missing Values Imputed',
#    'constraints': {'int': {'min': 0,
#      'max': 99999,
#      'supports_grid_search': False}}},
#   {'parameter_name': 'card_max',
#    'parameter_id': 'eyJhcmciOiJjYXJkX21heCIsInZpZCI6IjEifQ',
#    'default_value': 'None',
#    'current_value': 'None',
#    'task_name': 'Ordinal encoding of categorical variables',
#    'constraints': {'select': {'values': ['None']},
#     'int': {'min': 1, 'max': 9999999, 'supports_grid_search': False}}},
#   {'parameter_name': 'method',
#    'parameter_id': 'eyJhcmciOiJtZXRob2QiLCJ2aWQiOiIxIn0',
#    'default_value': 'freq',
#    'current_value': 'freq',
#    'task_name': 'Ordinal encoding of categorical variables',
#    'constraints': {'select': {'values': ['None',
#       'random',
#       'lex',
#       'freq',
#       'resp']}}},
#   {'parameter_name': 'min_support',
#    'parameter_id': 'eyJhcmciOiJtaW5fc3VwcG9ydCIsInZpZCI6IjEifQ',
#    'default_value': 5,
#    'current_value': 5,
#    'task_name': 'Ordinal encoding of categorical variables',
#    'constraints': {'int': {'min': 1,
#      'max': 99999,
#      'supports_grid_search': False}}},
#   {'parameter_name': 'base_margin_initialize',
#    'parameter_id': 'eyJhcmciOiJiYXNlX21hcmdpbl9pbml0aWFsaXplIiwidmlkIjoiMTIifQ',
#    'default_value': 'False',
#    'current_value': 'False',
#    'task_name': 'eXtreme Gradient Boosted Trees Classifier with Early Stopping',
#    'constraints': {'select': {'values': ['False', 'True']}}},
#   {'parameter_name': 'colsample_bylevel',
#    'parameter_id': 'eyJhcmciOiJjb2xzYW1wbGVfYnlsZXZlbCIsInZpZCI6IjEyIn0',
#    'default_value': 1,
#    'current_value': 1,
#    'task_name': 'eXtreme Gradient Boosted Trees Classifier with Early Stopping',
#    'constraints': {'float': {'min': 0.1,
#      'max': 1.0,
#      'supports_grid_search': True}}},
#   {'parameter_name': 'colsample_bytree',
#    'parameter_id': 'eyJhcmciOiJjb2xzYW1wbGVfYnl0cmVlIiwidmlkIjoiMTIifQ',
#    'default_value': 0.3,
#    'current_value': 0.3,
#    'task_name': 'eXtreme Gradient Boosted Trees Classifier with Early Stopping',
#    'constraints': {'float': {'min': 0.04,
#      'max': 1.0,
#      'supports_grid_search': True}}},
#   {'parameter_name': 'interval',
#    'parameter_id': 'eyJhcmciOiJpbnRlcnZhbCIsInZpZCI6IjEyIn0',
#    'default_value': 10,
#    'current_value': 10,
#    'task_name': 'eXtreme Gradient Boosted Trees Classifier with Early Stopping',
#    'constraints': {'int': {'min': 2,
#      'max': 500,
#      'supports_grid_search': False}}},
#   {'parameter_name': 'learning_rate',
#    'parameter_id': 'eyJhcmciOiJsZWFybmluZ19yYXRlIiwidmlkIjoiMTIifQ',
#    'default_value': 0.05,
#    'current_value': 0.05,
#    'task_name': 'eXtreme Gradient Boosted Trees Classifier with Early Stopping',
#    'constraints': {'float': {'min': 0.0005,
#      'max': 1.0,
#      'supports_grid_search': True}}},
#   {'parameter_name': 'max_bin',
#    'parameter_id': 'eyJhcmciOiJtYXhfYmluIiwidmlkIjoiMTIifQ',
#    'default_value': 256,
#    'current_value': 256,
#    'task_name': 'eXtreme Gradient Boosted Trees Classifier with Early Stopping',
#    'constraints': {'int': {'min': 16,
#      'max': 2048,
#      'supports_grid_search': True}}},
#   {'parameter_name': 'max_delta_step',
#    'parameter_id': 'eyJhcmciOiJtYXhfZGVsdGFfc3RlcCIsInZpZCI6IjEyIn0',
#    'default_value': 0,
#    'current_value': 0,
#    'task_name': 'eXtreme Gradient Boosted Trees Classifier with Early Stopping',
#    'constraints': {'float': {'min': 0.0,
#      'max': 100.0,
#      'supports_grid_search': True}}},
#   {'parameter_name': 'max_depth',
#    'parameter_id': 'eyJhcmciOiJtYXhfZGVwdGgiLCJ2aWQiOiIxMiJ9',
#    'default_value': 3,
#    'current_value': '[3, 5, 7]',
#    'task_name': 'eXtreme Gradient Boosted Trees Classifier with Early Stopping',
#    'constraints': {'int': {'min': 1,
#      'max': 16,
#      'supports_grid_search': True}}},
#   {'parameter_name': 'min_child_weight',
#    'parameter_id': 'eyJhcmciOiJtaW5fY2hpbGRfd2VpZ2h0IiwidmlkIjoiMTIifQ',
#    'default_value': 1,
#    'current_value': 1,
#    'task_name': 'eXtreme Gradient Boosted Trees Classifier with Early Stopping',
#    'constraints': {'float': {'min': 0.01,
#      'max': 100000.0,
#      'supports_grid_search': True}}},
#   {'parameter_name': 'min_split_loss',
#    'parameter_id': 'eyJhcmciOiJtaW5fc3BsaXRfbG9zcyIsInZpZCI6IjEyIn0',
#    'default_value': 0.01,
#    'current_value': 0.01,
#    'task_name': 'eXtreme Gradient Boosted Trees Classifier with Early Stopping',
#    'constraints': {'float': {'min': 0.0,
#      'max': 1.0,
#      'supports_grid_search': True}}},
#   {'parameter_name': 'missing_value',
#    'parameter_id': 'eyJhcmciOiJtaXNzaW5nX3ZhbHVlIiwidmlkIjoiMTIifQ',
#    'default_value': -9999,
#    'current_value': -9999,
#    'task_name': 'eXtreme Gradient Boosted Trees Classifier with Early Stopping',
#    'constraints': {'float': {'min': -100000.0,
#      'max': 100000.0,
#      'supports_grid_search': False}}},
#   {'parameter_name': 'n_estimators',
#    'parameter_id': 'eyJhcmciOiJuX2VzdGltYXRvcnMiLCJ2aWQiOiIxMiJ9',
#    'default_value': 2500,
#    'current_value': 2500,
#    'task_name': 'eXtreme Gradient Boosted Trees Classifier with Early Stopping',
#    'constraints': {'int': {'min': 1,
#      'max': 20000,
#      'supports_grid_search': False}}},
#   {'parameter_name': 'num_parallel_tree',
#    'parameter_id': 'eyJhcmciOiJudW1fcGFyYWxsZWxfdHJlZSIsInZpZCI6IjEyIn0',
#    'default_value': 1,
#    'current_value': 1,
#    'task_name': 'eXtreme Gradient Boosted Trees Classifier with Early Stopping',
#    'constraints': {'int': {'min': 1,
#      'max': 16,
#      'supports_grid_search': True}}},
#   {'parameter_name': 'random_state',
#    'parameter_id': 'eyJhcmciOiJyYW5kb21fc3RhdGUiLCJ2aWQiOiIxMiJ9',
#    'default_value': 1234,
#    'current_value': 1234,
#    'task_name': 'eXtreme Gradient Boosted Trees Classifier with Early Stopping',
#    'constraints': {'int': {'min': 0,
#      'max': 1000000000,
#      'supports_grid_search': True}}},
#   {'parameter_name': 'reg_alpha',
#    'parameter_id': 'eyJhcmciOiJyZWdfYWxwaGEiLCJ2aWQiOiIxMiJ9',
#    'default_value': 0,
#    'current_value': 0,
#    'task_name': 'eXtreme Gradient Boosted Trees Classifier with Early Stopping',
#    'constraints': {'float': {'min': 0.0,
#      'max': 1000000.0,
#      'supports_grid_search': True}}},
#   {'parameter_name': 'reg_lambda',
#    'parameter_id': 'eyJhcmciOiJyZWdfbGFtYmRhIiwidmlkIjoiMTIifQ',
#    'default_value': 1,
#    'current_value': 1,
#    'task_name': 'eXtreme Gradient Boosted Trees Classifier with Early Stopping',
#    'constraints': {'float': {'min': 0.0,
#      'max': 1000000.0,
#      'supports_grid_search': True}}},
#   {'parameter_name': 'scale_pos_weight',
#    'parameter_id': 'eyJhcmciOiJzY2FsZV9wb3Nfd2VpZ2h0IiwidmlkIjoiMTIifQ',
#    'default_value': 1,
#    'current_value': 1,
#    'task_name': 'eXtreme Gradient Boosted Trees Classifier with Early Stopping',
#    'constraints': {'float': {'min': 0.0,
#      'max': 1000000000.0,
#      'supports_grid_search': True}}},
#   {'parameter_name': 'smooth_interval',
#    'parameter_id': 'eyJhcmciOiJzbW9vdGhfaW50ZXJ2YWwiLCJ2aWQiOiIxMiJ9',
#    'default_value': 200,
#    'current_value': 200,
#    'task_name': 'eXtreme Gradient Boosted Trees Classifier with Early Stopping',
#    'constraints': {'int': {'min': 2,
#      'max': 1000,
#      'supports_grid_search': False}}},
#   {'parameter_name': 'subsample',
#    'parameter_id': 'eyJhcmciOiJzdWJzYW1wbGUiLCJ2aWQiOiIxMiJ9',
#    'default_value': 1,
#    'current_value': 1,
#    'task_name': 'eXtreme Gradient Boosted Trees Classifier with Early Stopping',
#    'constraints': {'float': {'min': 0.01,
#      'max': 1.0,
#      'supports_grid_search': True}}},
#   {'parameter_name': 'tree_method',
#    'parameter_id': 'eyJhcmciOiJ0cmVlX21ldGhvZCIsInZpZCI6IjEyIn0',
#    'default_value': 'auto',
#    'current_value': 'auto',
#    'task_name': 'eXtreme Gradient Boosted Trees Classifier with Early Stopping',
#    'constraints': {'select': {'values': ['auto',
#       'exact',
#       'approx',
#       'hist']}}}]}

# %%
# Retrieve parameters in a dataframe
prms = model.get_parameters()

prms_df = parameters_to_df(prms)
prms_df[['task_name','parameter_name','parameter_name_type','current_value', 'default_value','param_type',
         'supports_grid_search','min_val', 'max_val','values_select',
         'parameter_id']].sort_values(['task_name','parameter_name_type'])
# Out:
#                                             task_name          parameter_name  \
# 0                              Missing Values Imputed                  arbimp
# 1                              Missing Values Imputed            min_count_na
# 2           Ordinal encoding of categorical variables                card_max
# 25          Ordinal encoding of categorical variables                card_max
# 3           Ordinal encoding of categorical variables                  method
# 4           Ordinal encoding of categorical variables             min_support
# 5   eXtreme Gradient Boosted Trees Classifier with...  base_margin_initialize
# 6   eXtreme Gradient Boosted Trees Classifier with...       colsample_bylevel
# 7   eXtreme Gradient Boosted Trees Classifier with...        colsample_bytree
# 8   eXtreme Gradient Boosted Trees Classifier with...                interval
# 9   eXtreme Gradient Boosted Trees Classifier with...           learning_rate
# 10  eXtreme Gradient Boosted Trees Classifier with...                 max_bin
# 11  eXtreme Gradient Boosted Trees Classifier with...          max_delta_step
# 12  eXtreme Gradient Boosted Trees Classifier with...               max_depth
# 13  eXtreme Gradient Boosted Trees Classifier with...        min_child_weight
# 14  eXtreme Gradient Boosted Trees Classifier with...          min_split_loss
# 15  eXtreme Gradient Boosted Trees Classifier with...           missing_value
# 16  eXtreme Gradient Boosted Trees Classifier with...            n_estimators
# 17  eXtreme Gradient Boosted Trees Classifier with...       num_parallel_tree
# 18  eXtreme Gradient Boosted Trees Classifier with...            random_state
# 19  eXtreme Gradient Boosted Trees Classifier with...               reg_alpha
# 20  eXtreme Gradient Boosted Trees Classifier with...              reg_lambda
# 21  eXtreme Gradient Boosted Trees Classifier with...        scale_pos_weight
# 22  eXtreme Gradient Boosted Trees Classifier with...         smooth_interval
# 23  eXtreme Gradient Boosted Trees Classifier with...               subsample
# 24  eXtreme Gradient Boosted Trees Classifier with...             tree_method
#
#               parameter_name_type current_value default_value param_type  \
# 0                      arbimp_int         -9999         -9999        int
# 1                min_count_na_int             5             5        int
# 2                    card_max_int          None          None        int
# 25                card_max_select          None          None     select
# 3                   method_select          freq          freq     select
# 4                 min_support_int             5             5        int
# 5   base_margin_initialize_select         False         False     select
# 6         colsample_bylevel_float             1             1      float
# 7          colsample_bytree_float           0.3           0.3      float
# 8                    interval_int            10            10        int
# 9             learning_rate_float          0.05          0.05      float
# 10                    max_bin_int           256           256        int
# 11           max_delta_step_float             0             0      float
# 12                  max_depth_int     [3, 5, 7]             3        int
# 13         min_child_weight_float             1             1      float
# 14           min_split_loss_float          0.01          0.01      float
# 15            missing_value_float         -9999         -9999      float
# 16               n_estimators_int          2500          2500        int
# 17          num_parallel_tree_int             1             1        int
# 18               random_state_int          1234          1234        int
# 19                reg_alpha_float             0             0      float
# 20               reg_lambda_float             1             1      float
# 21         scale_pos_weight_float             1             1      float
# 22            smooth_interval_int           200           200        int
# 23                subsample_float             1             1      float
# 24             tree_method_select          auto          auto     select
#
#     supports_grid_search      min_val       max_val  \
# 0                  False  -99999.0000  9.999900e+04
# 1                  False       0.0000  9.999900e+04
# 2                  False       1.0000  9.999999e+06
# 25                 False          NaN           NaN
# 3                  False          NaN           NaN
# 4                  False       1.0000  9.999900e+04
# 5                  False          NaN           NaN
# 6                   True       0.1000  1.000000e+00
# 7                   True       0.0400  1.000000e+00
# 8                  False       2.0000  5.000000e+02
# 9                   True       0.0005  1.000000e+00
# 10                  True      16.0000  2.048000e+03
# 11                  True       0.0000  1.000000e+02
# 12                  True       1.0000  1.600000e+01
# 13                  True       0.0100  1.000000e+05
# 14                  True       0.0000  1.000000e+00
# 15                 False -100000.0000  1.000000e+05
# 16                 False       1.0000  2.000000e+04
# 17                  True       1.0000  1.600000e+01
# 18                  True       0.0000  1.000000e+09
# 19                  True       0.0000  1.000000e+06
# 20                  True       0.0000  1.000000e+06
# 21                  True       0.0000  1.000000e+09
# 22                 False       2.0000  1.000000e+03
# 23                  True       0.0100  1.000000e+00
# 24                 False          NaN           NaN
#
#                       values_select  \
# 0                              None
# 1                              None
# 2                              None
# 25                           [None]
# 3   [None, random, lex, freq, resp]
# 4                              None
# 5                     [False, True]
# 6                              None
# 7                              None
# 8                              None
# 9                              None
# 10                             None
# 11                             None
# 12                             None
# 13                             None
# 14                             None
# 15                             None
# 16                             None
# 17                             None
# 18                             None
# 19                             None
# 20                             None
# 21                             None
# 22                             None
# 23                             None
# 24      [auto, exact, approx, hist]
#
#                                          parameter_id
# 0                eyJhcmciOiJhcmJpbXAiLCJ2aWQiOiIxMSJ9
# 1        eyJhcmciOiJtaW5fY291bnRfbmEiLCJ2aWQiOiIxMSJ9
# 2              eyJhcmciOiJjYXJkX21heCIsInZpZCI6IjEifQ
# 25             eyJhcmciOiJjYXJkX21heCIsInZpZCI6IjEifQ
# 3                 eyJhcmciOiJtZXRob2QiLCJ2aWQiOiIxIn0
# 4          eyJhcmciOiJtaW5fc3VwcG9ydCIsInZpZCI6IjEifQ
# 5   eyJhcmciOiJiYXNlX21hcmdpbl9pbml0aWFsaXplIiwidm...
# 6   eyJhcmciOiJjb2xzYW1wbGVfYnlsZXZlbCIsInZpZCI6Ij...
# 7   eyJhcmciOiJjb2xzYW1wbGVfYnl0cmVlIiwidmlkIjoiMT...
# 8             eyJhcmciOiJpbnRlcnZhbCIsInZpZCI6IjEyIn0
# 9      eyJhcmciOiJsZWFybmluZ19yYXRlIiwidmlkIjoiMTIifQ
# 10             eyJhcmciOiJtYXhfYmluIiwidmlkIjoiMTIifQ
# 11    eyJhcmciOiJtYXhfZGVsdGFfc3RlcCIsInZpZCI6IjEyIn0
# 12           eyJhcmciOiJtYXhfZGVwdGgiLCJ2aWQiOiIxMiJ9
# 13  eyJhcmciOiJtaW5fY2hpbGRfd2VpZ2h0IiwidmlkIjoiMT...
# 14    eyJhcmciOiJtaW5fc3BsaXRfbG9zcyIsInZpZCI6IjEyIn0
# 15     eyJhcmciOiJtaXNzaW5nX3ZhbHVlIiwidmlkIjoiMTIifQ
# 16       eyJhcmciOiJuX2VzdGltYXRvcnMiLCJ2aWQiOiIxMiJ9
# 17  eyJhcmciOiJudW1fcGFyYWxsZWxfdHJlZSIsInZpZCI6Ij...
# 18       eyJhcmciOiJyYW5kb21fc3RhdGUiLCJ2aWQiOiIxMiJ9
# 19           eyJhcmciOiJyZWdfYWxwaGEiLCJ2aWQiOiIxMiJ9
# 20         eyJhcmciOiJyZWdfbGFtYmRhIiwidmlkIjoiMTIifQ
# 21  eyJhcmciOiJzY2FsZV9wb3Nfd2VpZ2h0IiwidmlkIjoiMT...
# 22   eyJhcmciOiJzbW9vdGhfaW50ZXJ2YWwiLCJ2aWQiOiIxMiJ9
# 23           eyJhcmciOiJzdWJzYW1wbGUiLCJ2aWQiOiIxMiJ9
# 24        eyJhcmciOiJ0cmVlX21ldGhvZCIsInZpZCI6IjEyIn0

# %%
tune = model.start_advanced_tuning_session()

# %%
model.get_advanced_tuning_parameters()
# Out:
# {'tuning_description': None,
#  'tuning_parameters': [{'parameter_name': 'arbimp',
#    'parameter_id': 'eyJhcmciOiJhcmJpbXAiLCJ2aWQiOiIxMSJ9',
#    'default_value': -9999,
#    'current_value': -9999,
#    'task_name': 'Missing Values Imputed',
#    'constraints': {'int': {'min': -99999,
#      'max': 99999,
#      'supports_grid_search': False}}},
#   {'parameter_name': 'min_count_na',
#    'parameter_id': 'eyJhcmciOiJtaW5fY291bnRfbmEiLCJ2aWQiOiIxMSJ9',
#    'default_value': 5,
#    'current_value': 5,
#    'task_name': 'Missing Values Imputed',
#    'constraints': {'int': {'min': 0,
#      'max': 99999,
#      'supports_grid_search': False}}},
#   {'parameter_name': 'card_max',
#    'parameter_id': 'eyJhcmciOiJjYXJkX21heCIsInZpZCI6IjEifQ',
#    'default_value': 'None',
#    'current_value': 'None',
#    'task_name': 'Ordinal encoding of categorical variables',
#    'constraints': {'select': {'values': ['None']},
#     'int': {'min': 1, 'max': 9999999, 'supports_grid_search': False}}},
#   {'parameter_name': 'method',
#    'parameter_id': 'eyJhcmciOiJtZXRob2QiLCJ2aWQiOiIxIn0',
#    'default_value': 'freq',
#    'current_value': 'freq',
#    'task_name': 'Ordinal encoding of categorical variables',
#    'constraints': {'select': {'values': ['None',
#       'random',
#       'lex',
#       'freq',
#       'resp']}}},
#   {'parameter_name': 'min_support',
#    'parameter_id': 'eyJhcmciOiJtaW5fc3VwcG9ydCIsInZpZCI6IjEifQ',
#    'default_value': 5,
#    'current_value': 5,
#    'task_name': 'Ordinal encoding of categorical variables',
#    'constraints': {'int': {'min': 1,
#      'max': 99999,
#      'supports_grid_search': False}}},
#   {'parameter_name': 'base_margin_initialize',
#    'parameter_id': 'eyJhcmciOiJiYXNlX21hcmdpbl9pbml0aWFsaXplIiwidmlkIjoiMTIifQ',
#    'default_value': 'False',
#    'current_value': 'False',
#    'task_name': 'eXtreme Gradient Boosted Trees Classifier with Early Stopping',
#    'constraints': {'select': {'values': ['False', 'True']}}},
#   {'parameter_name': 'colsample_bylevel',
#    'parameter_id': 'eyJhcmciOiJjb2xzYW1wbGVfYnlsZXZlbCIsInZpZCI6IjEyIn0',
#    'default_value': 1,
#    'current_value': 1,
#    'task_name': 'eXtreme Gradient Boosted Trees Classifier with Early Stopping',
#    'constraints': {'float': {'min': 0.1,
#      'max': 1.0,
#      'supports_grid_search': True}}},
#   {'parameter_name': 'colsample_bytree',
#    'parameter_id': 'eyJhcmciOiJjb2xzYW1wbGVfYnl0cmVlIiwidmlkIjoiMTIifQ',
#    'default_value': 0.3,
#    'current_value': 0.3,
#    'task_name': 'eXtreme Gradient Boosted Trees Classifier with Early Stopping',
#    'constraints': {'float': {'min': 0.04,
#      'max': 1.0,
#      'supports_grid_search': True}}},
#   {'parameter_name': 'interval',
#    'parameter_id': 'eyJhcmciOiJpbnRlcnZhbCIsInZpZCI6IjEyIn0',
#    'default_value': 10,
#    'current_value': 10,
#    'task_name': 'eXtreme Gradient Boosted Trees Classifier with Early Stopping',
#    'constraints': {'int': {'min': 2,
#      'max': 500,
#      'supports_grid_search': False}}},
#   {'parameter_name': 'learning_rate',
#    'parameter_id': 'eyJhcmciOiJsZWFybmluZ19yYXRlIiwidmlkIjoiMTIifQ',
#    'default_value': 0.05,
#    'current_value': 0.05,
#    'task_name': 'eXtreme Gradient Boosted Trees Classifier with Early Stopping',
#    'constraints': {'float': {'min': 0.0005,
#      'max': 1.0,
#      'supports_grid_search': True}}},
#   {'parameter_name': 'max_bin',
#    'parameter_id': 'eyJhcmciOiJtYXhfYmluIiwidmlkIjoiMTIifQ',
#    'default_value': 256,
#    'current_value': 256,
#    'task_name': 'eXtreme Gradient Boosted Trees Classifier with Early Stopping',
#    'constraints': {'int': {'min': 16,
#      'max': 2048,
#      'supports_grid_search': True}}},
#   {'parameter_name': 'max_delta_step',
#    'parameter_id': 'eyJhcmciOiJtYXhfZGVsdGFfc3RlcCIsInZpZCI6IjEyIn0',
#    'default_value': 0,
#    'current_value': 0,
#    'task_name': 'eXtreme Gradient Boosted Trees Classifier with Early Stopping',
#    'constraints': {'float': {'min': 0.0,
#      'max': 100.0,
#      'supports_grid_search': True}}},
#   {'parameter_name': 'max_depth',
#    'parameter_id': 'eyJhcmciOiJtYXhfZGVwdGgiLCJ2aWQiOiIxMiJ9',
#    'default_value': 3,
#    'current_value': '[3, 5, 7]',
#    'task_name': 'eXtreme Gradient Boosted Trees Classifier with Early Stopping',
#    'constraints': {'int': {'min': 1,
#      'max': 16,
#      'supports_grid_search': True}}},
#   {'parameter_name': 'min_child_weight',
#    'parameter_id': 'eyJhcmciOiJtaW5fY2hpbGRfd2VpZ2h0IiwidmlkIjoiMTIifQ',
#    'default_value': 1,
#    'current_value': 1,
#    'task_name': 'eXtreme Gradient Boosted Trees Classifier with Early Stopping',
#    'constraints': {'float': {'min': 0.01,
#      'max': 100000.0,
#      'supports_grid_search': True}}},
#   {'parameter_name': 'min_split_loss',
#    'parameter_id': 'eyJhcmciOiJtaW5fc3BsaXRfbG9zcyIsInZpZCI6IjEyIn0',
#    'default_value': 0.01,
#    'current_value': 0.01,
#    'task_name': 'eXtreme Gradient Boosted Trees Classifier with Early Stopping',
#    'constraints': {'float': {'min': 0.0,
#      'max': 1.0,
#      'supports_grid_search': True}}},
#   {'parameter_name': 'missing_value',
#    'parameter_id': 'eyJhcmciOiJtaXNzaW5nX3ZhbHVlIiwidmlkIjoiMTIifQ',
#    'default_value': -9999,
#    'current_value': -9999,
#    'task_name': 'eXtreme Gradient Boosted Trees Classifier with Early Stopping',
#    'constraints': {'float': {'min': -100000.0,
#      'max': 100000.0,
#      'supports_grid_search': False}}},
#   {'parameter_name': 'n_estimators',
#    'parameter_id': 'eyJhcmciOiJuX2VzdGltYXRvcnMiLCJ2aWQiOiIxMiJ9',
#    'default_value': 2500,
#    'current_value': 2500,
#    'task_name': 'eXtreme Gradient Boosted Trees Classifier with Early Stopping',
#    'constraints': {'int': {'min': 1,
#      'max': 20000,
#      'supports_grid_search': False}}},
#   {'parameter_name': 'num_parallel_tree',
#    'parameter_id': 'eyJhcmciOiJudW1fcGFyYWxsZWxfdHJlZSIsInZpZCI6IjEyIn0',
#    'default_value': 1,
#    'current_value': 1,
#    'task_name': 'eXtreme Gradient Boosted Trees Classifier with Early Stopping',
#    'constraints': {'int': {'min': 1,
#      'max': 16,
#      'supports_grid_search': True}}},
#   {'parameter_name': 'random_state',
#    'parameter_id': 'eyJhcmciOiJyYW5kb21fc3RhdGUiLCJ2aWQiOiIxMiJ9',
#    'default_value': 1234,
#    'current_value': 1234,
#    'task_name': 'eXtreme Gradient Boosted Trees Classifier with Early Stopping',
#    'constraints': {'int': {'min': 0,
#      'max': 1000000000,
#      'supports_grid_search': True}}},
#   {'parameter_name': 'reg_alpha',
#    'parameter_id': 'eyJhcmciOiJyZWdfYWxwaGEiLCJ2aWQiOiIxMiJ9',
#    'default_value': 0,
#    'current_value': 0,
#    'task_name': 'eXtreme Gradient Boosted Trees Classifier with Early Stopping',
#    'constraints': {'float': {'min': 0.0,
#      'max': 1000000.0,
#      'supports_grid_search': True}}},
#   {'parameter_name': 'reg_lambda',
#    'parameter_id': 'eyJhcmciOiJyZWdfbGFtYmRhIiwidmlkIjoiMTIifQ',
#    'default_value': 1,
#    'current_value': 1,
#    'task_name': 'eXtreme Gradient Boosted Trees Classifier with Early Stopping',
#    'constraints': {'float': {'min': 0.0,
#      'max': 1000000.0,
#      'supports_grid_search': True}}},
#   {'parameter_name': 'scale_pos_weight',
#    'parameter_id': 'eyJhcmciOiJzY2FsZV9wb3Nfd2VpZ2h0IiwidmlkIjoiMTIifQ',
#    'default_value': 1,
#    'current_value': 1,
#    'task_name': 'eXtreme Gradient Boosted Trees Classifier with Early Stopping',
#    'constraints': {'float': {'min': 0.0,
#      'max': 1000000000.0,
#      'supports_grid_search': True}}},
#   {'parameter_name': 'smooth_interval',
#    'parameter_id': 'eyJhcmciOiJzbW9vdGhfaW50ZXJ2YWwiLCJ2aWQiOiIxMiJ9',
#    'default_value': 200,
#    'current_value': 200,
#    'task_name': 'eXtreme Gradient Boosted Trees Classifier with Early Stopping',
#    'constraints': {'int': {'min': 2,
#      'max': 1000,
#      'supports_grid_search': False}}},
#   {'parameter_name': 'subsample',
#    'parameter_id': 'eyJhcmciOiJzdWJzYW1wbGUiLCJ2aWQiOiIxMiJ9',
#    'default_value': 1,
#    'current_value': 1,
#    'task_name': 'eXtreme Gradient Boosted Trees Classifier with Early Stopping',
#    'constraints': {'float': {'min': 0.01,
#      'max': 1.0,
#      'supports_grid_search': True}}},
#   {'parameter_name': 'tree_method',
#    'parameter_id': 'eyJhcmciOiJ0cmVlX21ldGhvZCIsInZpZCI6IjEyIn0',
#    'default_value': 'auto',
#    'current_value': 'auto',
#    'task_name': 'eXtreme Gradient Boosted Trees Classifier with Early Stopping',
#    'constraints': {'select': {'values': ['auto',
#       'exact',
#       'approx',
#       'hist']}}}]}

# %%
# Set parameter values for a new run
tune.set_parameter(parameter_name='threshold', value=70)

# %%
# Run with new values
job = tune.run()

# %% [markdown]
# #### Retrieve model coefficients

# %%
dict_derived_features = dr.Model.get(project=selected_project, model_id=selected_model).get_parameters().derived_features
df_derived_features = pd.DataFrame(dict_derived_features)[['original_feature','derived_feature','coefficient']]
df_derived_features
# Out:
#         original_feature                               derived_feature  \
# 0             addr_state                                 addr_state-AZ
# 1             addr_state                                 addr_state-CA
# 2             addr_state                                 addr_state-CO
# 3             addr_state                                 addr_state-CT
# 4             addr_state                                 addr_state-FL
# 5             addr_state                                 addr_state-GA
# 6             addr_state                                 addr_state-IL
# 7             addr_state                                 addr_state-MA
# 8             addr_state                                 addr_state-MD
# 9             addr_state                                 addr_state-MI
# 10            addr_state                                 addr_state-MO
# 11            addr_state                                 addr_state-NC
# 12            addr_state                                 addr_state-NJ
# 13            addr_state                                 addr_state-NY
# 14            addr_state                                 addr_state-OH
# 15            addr_state                                 addr_state-OR
# 16            addr_state                                 addr_state-PA
# 17            addr_state                                 addr_state-TX
# 18            addr_state                                 addr_state-VA
# 19            addr_state                                 addr_state-WA
# 20            addr_state                        addr_state-small_count
# 21            annual_inc                   CONST_SPLINE_LOW_annual_inc
# 22            annual_inc               CONST_SPLINE_MED-LOW_annual_inc
# 23            annual_inc                   CONST_SPLINE_MED_annual_inc
# 24            annual_inc              CONST_SPLINE_MED-HIGH_annual_inc
# 25            annual_inc                  CONST_SPLINE_HIGH_annual_inc
# 26           delinq_2yrs                 CONST_SPLINE_HIGH_delinq_2yrs
# 27                   dti                          CONST_SPLINE_LOW_dti
# 28                   dti                      CONST_SPLINE_MED-LOW_dti
# 29                   dti                          CONST_SPLINE_MED_dti
# ..                   ...                                           ...
# 146            sub_grade                                  sub_grade-A5
# 147            sub_grade                                  sub_grade-B1
# 148            sub_grade                                  sub_grade-B2
# 149            sub_grade                                  sub_grade-B3
# 150            sub_grade                                  sub_grade-B4
# 151            sub_grade                                  sub_grade-B5
# 152            sub_grade                                  sub_grade-C1
# 153            sub_grade                                  sub_grade-C2
# 154            sub_grade                                  sub_grade-C3
# 155            sub_grade                                  sub_grade-C4
# 156            sub_grade                                  sub_grade-C5
# 157            sub_grade                                  sub_grade-D1
# 158            sub_grade                                  sub_grade-D2
# 159            sub_grade                                  sub_grade-D3
# 160            sub_grade                                  sub_grade-D4
# 161            sub_grade                                  sub_grade-D5
# 162            sub_grade                                  sub_grade-E1
# 163            sub_grade                                  sub_grade-E2
# 164            sub_grade                                  sub_grade-E3
# 165            sub_grade                         sub_grade-small_count
# 166                 term                               term- 60 months
# 167            total_acc                    CONST_SPLINE_LOW_total_acc
# 168            total_acc                CONST_SPLINE_MED-LOW_total_acc
# 169            total_acc                    CONST_SPLINE_MED_total_acc
# 170            total_acc               CONST_SPLINE_MED-HIGH_total_acc
# 171            total_acc                   CONST_SPLINE_HIGH_total_acc
# 172  verification_status         verification_status-VERIFIED - income
# 173  verification_status  verification_status-VERIFIED - income source
# 174  verification_status              verification_status-not verified
# 175             zip_code                                zip_code-112xx
#
#      coefficient
# 0       0.078547
# 1       0.030598
# 2      -0.031749
# 3       0.012494
# 4      -0.012211
# 5      -0.020870
# 6      -0.118720
# 7       0.014594
# 8      -0.052028
# 9      -0.038519
# 10      0.030758
# 11      0.089295
# 12     -0.016354
# 13     -0.088997
# 14     -0.014114
# 15      0.015067
# 16     -0.103765
# 17     -0.019422
# 18     -0.009021
# 19     -0.046481
# 20     -0.019843
# 21      0.133284
# 22     -0.017709
# 23     -0.013830
# 24     -0.102022
# 25     -0.320466
# 26      0.054665
# 27     -0.041351
# 28     -0.152572
# 29     -0.061370
# ..           ...
# 146    -0.046568
# 147    -0.113194
# 148    -0.047273
# 149     0.038467
# 150    -0.060368
# 151    -0.012390
# 152     0.002947
# 153     0.008329
# 154     0.046913
# 155    -0.050511
# 156     0.088731
# 157    -0.056920
# 158    -0.023170
# 159     0.114743
# 160    -0.066064
# 161    -0.021983
# 162     0.017845
# 163     0.171829
# 164     0.021283
# 165    -0.012968
# 166     0.259226
# 167     0.038233
# 168    -0.071406
# 169    -0.051622
# 170    -0.037081
# 171    -0.198867
# 172    -0.030036
# 173    -0.055214
# 174    -0.235492
# 175    -0.026509
#
# [176 rows x 3 columns]
